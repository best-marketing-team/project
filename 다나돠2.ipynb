# %%
#콜라겐/엽산
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
driver=webdriver.Chrome("C:/Users/689/jisu/chromedriver_win32/chromedriver.exe")
url= 'http://prod.danawa.com/list/?cate=1632327'
driver.get(url)

try:
    list=driver.find_elements_by_class_name("prod_name")
    for div in list:
        print(div.text)
    list2=driver.find_elements_by_class_name("prod_spec_set")
    for li in list2:
        print(li.text)
        time.sleep(1)

except NoSuchElementException:
    print("No element found")
# Out:
# 녹십초생활건강 쏘팔메토 옥타코사놀 30캡슐 (6개)
# 녹십초생활건강 쏘팔메토 옥타코사놀 30캡슐 (6개)
# 1 뉴트리 에버콜라겐 인앤업 플러스 56정
# 2 농심 라이필 더마 콜라겐 84정
# 3 뉴트리 에버콜라겐 타임 비오틴 30포
# 4 뉴트리 에버콜라겐 타임 30포
# 5 뉴트리원 비비랩 더 콜라겐 파우더 S 30포
# 6 광동제약 광동초이스 더 탱탱한 석류콜라겐 젤리스틱 10포
# 7 드랍쉽 저분자 피쉬콜라겐 분말 1kg
# 8 뉴트리코어 콜라겐 담다 15포
# 9 에이치케이이노엔 뉴틴 타트체리 콜라겐 스틱 30포
# 10 순수식품 진짜석류 15포
# 11 대상웰라이프 석류 콜라겐 15포
# 12 아모레퍼시픽 바이탈뷰티 슈퍼콜라겐 30앰플
# 13 뉴트리원 르 시크릿 더 석류콜라겐 14포
# 14 종근당건강 아쿠아 콜라겐 30포
# 15 일동생활건강 일동 저분자 피쉬콜라겐C 30포
# 16 뉴트리원 뉴트리원라이프 비비랩 저분자 콜라겐 30포
# 17 중외제약 유기농 프리미엄 리얼메디 석류젤리스틱 마스터 15포
# 18 제너럴밸런스 N 콜라겐 30포
# 19 사람과자연 초저분자 피쉬 콜라겐 트리펩타이드 300g
# 20 순수식품 저분자 콜라겐 500달톤 90정
# 21 트래디스바이오 더작 저분자 콜라겐 타블렛 60정
# 22 푸른건강 피쉬 콜라겐 지퍼팩 300g
# 23 일양약품 콜라겐 톡톡 120스틱
# 24 보뚜슈퍼푸드 몽모랑시 타트체리 콜라겐 15포
# 25 뉴트리 에버콜라겐 코큐 84정
# 26 종근당건강 올앳미 어린슈퍼콜라겐 스킨핏 30포
# 27 웰츄럴 빨간스캔들 RED 석류 10포
# 28 헬스밸런스 스키니랩 뷰티풀 석류 14포
# 29 GC녹십자 석류콜라겐 1.2 60포
# 30 홀푸드 홀핏 피부애 어린콜라겐 비타민C 150정
#
# 쏘팔메토 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 / 총량: 30캡슐 x 6개 / 섭취기간: 180일 / 인증: 건강기능식품, GMP /
# ...

# %%
#오메가3/크릴오일
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
driver=webdriver.Chrome("C:/Users/689/jisu/chromedriver_win32/chromedriver.exe")
url= 'http://prod.danawa.com/list/?cate=1632328'
driver.get(url)

try:
    list=driver.find_elements_by_class_name("prod_name")
    for div in list:
        print(div.text)
        
    list2=driver.find_elements_by_class_name("prod_spec_set")
    for li in list2:
        print(li.text)
        time.sleep(1)

except NoSuchElementException:
    print("No element found")
# Out:
# 녹십초생활건강 쏘팔메토 옥타코사놀 30캡슐 (6개)
# 녹십초생활건강 쏘팔메토 옥타코사놀 30캡슐 (6개)
# 1 종근당건강 프로메가 알티지 오메가3 60캡슐
# 2 내츄럴플러스 알티지 오메가3 1200 180캡슐
# 3 메이플트리 오메가-3 맥스 1100 180캡슐
# 4 펄세스 크릴56 30캡슐
# 5 지엔엠라이프 GNM자연의품격 rTG알티지 오메가3 60캡슐
# 6 종근당건강 프로메가 오메가3 파워 60캡슐
# 7 스포츠리서치 오메가3 피쉬 오일 180캡슐 (해외)
# 8 중외제약 프리미엄 리얼메디 크릴오일 58 30캡슐
# 9 에스더포뮬러 파이토 오메가 플러스D 1000IU 60캡슐
# 10 코스트코 커클랜드 슈퍼 오메가3 180캡슐
# 11 지엔엠라이프 GNM자연의품격 크릴오일맥스 1000 30캡슐
# 12 내츄럴플러스 프리미엄 오메가3 1100 180캡슐
# 13 고려은단 퓨어 알티지 오메가3 60캡슐
# 14 뉴트리코어 식물성 알티지 오메가3 30캡슐
# 15 네추럴라이즈 엔쵸비 오메가-3 1000 180캡슐
# 16 코스트코 커클랜드 크릴오일 160캡슐 (해외)
# 17 헬스밸런스 베스처 오메가-3 골드 1100 180캡슐
# 18 지엔엠라이프 GNM자연의품격 루테인오메가3 30캡슐
# 19 나우푸드 오메가-3 500캡슐 (해외)
# 20 노르딕내츄럴 오메가-3 180캡슐 (해외)
# 20 유니시티 오메가 라이프-3 리졸브 120캡슐
# 22 내츄럴플러스 알티지 오메가3 1200 60캡슐
# 23 쉬프 메가레드 오메가-3 크릴오일 1000mg 60정
# 24 네이처스토리 데일리원 리얼 알티지 오메가3 1200 60캡슐
# 25 부광메디카 파워 크릴오일 1000 30캡슐
# 26 우리가스토리 프리미엄 엔초비 오메가3 180캡슐
# 27 내츄럴라이프뉴트리션 데일리베스트 알티지 오메가-3 180캡슐
# 28 종근당건강 프로메가 기억력 오메가3 60캡슐
# 29 파마젠 알티지 오메가3 180캡슐
# 30 통라이프 슈퍼골드 오메가3 1300 60캡슐
# ...

# %%
#콜라겐
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
driver = webdriver.Chrome('C:/Users/689/jisu/chromedriver_win32/chromedriver.exe')
url= 'http://prod.danawa.com/list/?cate=1632327'
driver.get(url)


yeobsan_names = []
yeobsan_comps = []

try:
    list = driver.find_elements_by_class_name("prod_name")
    for div in list:
        yeobsan_names.append(div.text)
        
    list2=driver.find_elements_by_class_name("prod_spec_set")
    for li in list2:
        yeobsan_comps.append(li.text)
        time.sleep(1)

except NoSuchElementException:
    print("No element found")

# %%
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
driver = webdriver.Chrome('C:/Users/689/jisu/chromedriver_win32/chromedriver.exe')
url= 'http://prod.danawa.com/list/?cate=1632328'
driver.get(url)


omega_names = []
omega_comps = []

try:
    list = driver.find_elements_by_class_name("prod_name")
    for div in list:
        omega_names.append(div.text)
        
    list2=driver.find_elements_by_class_name("prod_spec_set")
    for li in list2:
        omega_comps.append(li.text)
        time.sleep(1)

except NoSuchElementException:
    print("No element found")

# %%
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
driver = webdriver.Chrome('C:/Users/689/jisu/chromedriver_win32/chromedriver.exe')
url= 'http://prod.danawa.com/list/?cate=1632325'
driver.get(url)


milk_names = []
milk_comps = []

try:
    list = driver.find_elements_by_class_name("prod_name")
    for div in list:
        milk_names.append(div.text)
        
    list2=driver.find_elements_by_class_name("prod_spec_set")
    for li in list2:
        milk_comps.append(li.text)
        time.sleep(1)

except NoSuchElementException:
    print("No element found")

# %%
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
driver = webdriver.Chrome('C:/Users/689/jisu/chromedriver_win32/chromedriver.exe')
url= 'http://prod.danawa.com/list/?cate=16319068'
driver.get(url)


sig2_names = []
sig2_comps = []

try:
    list = driver.find_elements_by_class_name("prod_name")
    for div in list:
        sig2_names.append(div.text)
        
    list2=driver.find_elements_by_class_name("prod_spec_set")
    for li in list2:
        sig2_comps.append(li.text)
        time.sleep(1)

except NoSuchElementException:
    print("No element found")

# %%
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
driver = webdriver.Chrome('C:/Users/689/jisu/chromedriver_win32/chromedriver.exe')
url= 'http://prod.danawa.com/list/?cate=1632320'
driver.get(url)

lutain_names = []
lutain_comps = []

try:
    list = driver.find_elements_by_class_name("prod_name")
    for div in list:
        lutain_names.append(div.text)
        
    list2=driver.find_elements_by_class_name("prod_spec_set")
    for li in list2:
        lutain_comps.append(li.text)
        time.sleep(1)

except NoSuchElementException:
    print("No element found")

# %%
from pandas import DataFrame
yeobsan_names_df = DataFrame(yeobsan_names,columns=["yeobsan_name"])
yeobsan_names_df
# Out:
#                             yeobsan_name
# 0           녹십초생활건강 쏘팔메토 옥타코사놀 30캡슐 (6개)
# 1           녹십초생활건강 쏘팔메토 옥타코사놀 30캡슐 (6개)
# 2                1 뉴트리 에버콜라겐 인앤업 플러스 56정
# 3                    2 농심 라이필 더마 콜라겐 84정
# 4                 3 뉴트리 에버콜라겐 타임 비오틴 30포
# 5                     4 뉴트리 에버콜라겐 타임 30포
# 6             5 뉴트리원 비비랩 더 콜라겐 파우더 S 30포
# 7      6 광동제약 광동초이스 더 탱탱한 석류콜라겐 젤리스틱 10포
# 8                 7 드랍쉽 저분자 피쉬콜라겐 분말 1kg
# 9                     8 뉴트리코어 콜라겐 담다 15포
# 10         9 에이치케이이노엔 뉴틴 타트체리 콜라겐 스틱 30포
# 11                      10 순수식품 진짜석류 15포
# 12                  11 대상웰라이프 석류 콜라겐 15포
# 13            12 아모레퍼시픽 바이탈뷰티 슈퍼콜라겐 30앰플
# 14             13 뉴트리원 르 시크릿 더 석류콜라겐 14포
# 15                  14 종근당건강 아쿠아 콜라겐 30포
# 16           15 일동생활건강 일동 저분자 피쉬콜라겐C 30포
# 17       16 뉴트리원 뉴트리원라이프 비비랩 저분자 콜라겐 30포
# 18  17 중외제약 유기농 프리미엄 리얼메디 석류젤리스틱 마스터 15포
# 19                   18 제너럴밸런스 N 콜라겐 30포
# 20      19 사람과자연 초저분자 피쉬 콜라겐 트리펩타이드 300g
# 21             20 순수식품 저분자 콜라겐 500달톤 90정
# ...

# %%
yeobsan_names_df.drop_duplicates()
yeobsan_names_df=yeobsan_names_df.drop(index=0)
yeobsan_names_df=yeobsan_names_df.drop(index=1)

# %%
yeobsan_names_df=yeobsan_names_df.reset_index(drop=True)

# %%
yeobsan_names_df
# Out:
#                             yeobsan_name
# 0                1 뉴트리 에버콜라겐 인앤업 플러스 56정
# 1                    2 농심 라이필 더마 콜라겐 84정
# 2                 3 뉴트리 에버콜라겐 타임 비오틴 30포
# 3                     4 뉴트리 에버콜라겐 타임 30포
# 4             5 뉴트리원 비비랩 더 콜라겐 파우더 S 30포
# 5      6 광동제약 광동초이스 더 탱탱한 석류콜라겐 젤리스틱 10포
# 6                 7 드랍쉽 저분자 피쉬콜라겐 분말 1kg
# 7                     8 뉴트리코어 콜라겐 담다 15포
# 8          9 에이치케이이노엔 뉴틴 타트체리 콜라겐 스틱 30포
# 9                       10 순수식품 진짜석류 15포
# 10                  11 대상웰라이프 석류 콜라겐 15포
# 11            12 아모레퍼시픽 바이탈뷰티 슈퍼콜라겐 30앰플
# 12             13 뉴트리원 르 시크릿 더 석류콜라겐 14포
# 13                  14 종근당건강 아쿠아 콜라겐 30포
# 14           15 일동생활건강 일동 저분자 피쉬콜라겐C 30포
# 15       16 뉴트리원 뉴트리원라이프 비비랩 저분자 콜라겐 30포
# 16  17 중외제약 유기농 프리미엄 리얼메디 석류젤리스틱 마스터 15포
# 17                   18 제너럴밸런스 N 콜라겐 30포
# 18      19 사람과자연 초저분자 피쉬 콜라겐 트리펩타이드 300g
# 19             20 순수식품 저분자 콜라겐 500달톤 90정
# 20         21 트래디스바이오 더작 저분자 콜라겐 타블렛 60정
# 21               22 푸른건강 피쉬 콜라겐 지퍼팩 300g
# ...

# %%
from pandas import DataFrame
yeobsan_comps_df = DataFrame(yeobsan_comps,columns=["yeobsan_comp"])
yeobsan_comps_df
# Out:
#                                          yeobsan_comp
# 0   쏘팔메토 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 1   콜라겐 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 2정 / ...
# 2   콜라겐 / 형태: 캡슐,정 / 섭취횟수, 양: 1일 1회, 1회 3정 / 총량: 8...
# 3   콜라겐 / 형태: 분말 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량: 30포...
# 4   콜라겐 / 형태: 분말 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량...
# 5   콜라겐 / 형태: 분말 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량...
# 6   콜라겐 / 형태: 젤리형 / 성인 / 섭취횟수, 양: 1일 1~2회, 1회 1포 /...
# 7   콜라겐 / 형태: 분말 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1.5g / ...
# 8   콜라겐 / 형태: 음료,추출액 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량:...
# 9   콜라겐 / 형태: 젤리형 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량: 30...
# 10  콜라겐 / 형태: 젤리형 / 섭취횟수, 양: 1일 1~2회, 1회 1포 / 총량: ...
# 11  콜라겐 / 형태: 분말 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량: 15포...
# 12  콜라겐 / 형태: 음료,추출액 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1앰플...
# 13  콜라겐 / 형태: 젤리형 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량: 14...
# 14  콜라겐 / 형태: 분말 / 성인 / 섭취횟수, 양: 1일 1~2회, 1회 1포 / ...
# 15  콜라겐 / 형태: 분말 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량...
# ...

# %%
yeobsan_comps_df=yeobsan_comps_df.drop(index=0)
yeobsan_comps_df=yeobsan_comps_df.reset_index(drop=True)

# %%
yeobsan_comps_df
# Out:
#                                          yeobsan_comp
# 0   콜라겐 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 2정 / ...
# 1   콜라겐 / 형태: 캡슐,정 / 섭취횟수, 양: 1일 1회, 1회 3정 / 총량: 8...
# 2   콜라겐 / 형태: 분말 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량: 30포...
# 3   콜라겐 / 형태: 분말 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량...
# 4   콜라겐 / 형태: 분말 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량...
# 5   콜라겐 / 형태: 젤리형 / 성인 / 섭취횟수, 양: 1일 1~2회, 1회 1포 /...
# 6   콜라겐 / 형태: 분말 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1.5g / ...
# 7   콜라겐 / 형태: 음료,추출액 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량:...
# 8   콜라겐 / 형태: 젤리형 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량: 30...
# 9   콜라겐 / 형태: 젤리형 / 섭취횟수, 양: 1일 1~2회, 1회 1포 / 총량: ...
# 10  콜라겐 / 형태: 분말 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량: 15포...
# 11  콜라겐 / 형태: 음료,추출액 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1앰플...
# 12  콜라겐 / 형태: 젤리형 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량: 14...
# 13  콜라겐 / 형태: 분말 / 성인 / 섭취횟수, 양: 1일 1~2회, 1회 1포 / ...
# 14  콜라겐 / 형태: 분말 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량...
# 15  콜라겐 / 형태: 분말 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량...
# ...

# %%
### 킵
import pandas as pd
yeobsan_df=pd.concat([yeobsan_names_df,yeobsan_comps_df],axis=1)
yeobsan_df.head(10)
# Out:
#                         yeobsan_name  \
# 0            1 뉴트리 에버콜라겐 인앤업 플러스 56정
# 1                2 농심 라이필 더마 콜라겐 84정
# 2             3 뉴트리 에버콜라겐 타임 비오틴 30포
# 3                 4 뉴트리 에버콜라겐 타임 30포
# 4         5 뉴트리원 비비랩 더 콜라겐 파우더 S 30포
# 5  6 광동제약 광동초이스 더 탱탱한 석류콜라겐 젤리스틱 10포
# 6             7 드랍쉽 저분자 피쉬콜라겐 분말 1kg
# 7                 8 뉴트리코어 콜라겐 담다 15포
# 8      9 에이치케이이노엔 뉴틴 타트체리 콜라겐 스틱 30포
# 9                   10 순수식품 진짜석류 15포
#
#                                         yeobsan_comp
# 0  콜라겐 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 2정 / ...
# 1  콜라겐 / 형태: 캡슐,정 / 섭취횟수, 양: 1일 1회, 1회 3정 / 총량: 8...
# 2  콜라겐 / 형태: 분말 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량: 30포...
# 3  콜라겐 / 형태: 분말 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량...
# 4  콜라겐 / 형태: 분말 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량...
# 5  콜라겐 / 형태: 젤리형 / 성인 / 섭취횟수, 양: 1일 1~2회, 1회 1포 /...
# 6  콜라겐 / 형태: 분말 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1.5g / ...
# 7  콜라겐 / 형태: 음료,추출액 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량:...
# 8  콜라겐 / 형태: 젤리형 / 섭취횟수, 양: 1일 1회, 1회 1포 / 총량: 30...
# ...

# %%
from pandas import DataFrame
yeobsan_names_df = DataFrame(yeobsan_names,columns=["yeobsan_name"])
yeobsan_names_df
yeobsan_names_df.drop_duplicates()
# yeobsan_names_df=yeobsan_names_df.drop(index=0)
yeobsan_names_df=yeobsan_names_df.drop(index=1)
yeobsan_names_df=yeobsan_names_df.reset_index(drop=True)
from pandas import DataFrame
yeobsan_comps_df = DataFrame(yeobsan_comps,columns=["yeobsan_comp"])
yeobsan_comps_df
yeobsan_comps_df=yeobsan_comps_df.drop(index=0)
yeobsan_comps_df=yeobsan_comps_df.reset_index(drop=True)
import pandas as pd
yeobsan_df=pd.concat([yeobsan_names_df,yeobsan_comps_df],axis=1)
yeobsan_df.head(10)

# %%
from pandas import DataFrame
omega_names_df = DataFrame(omega_names,columns=["omega_name"])
omega_names_df
# Out:
#                               omega_name
# 0           녹십초생활건강 쏘팔메토 옥타코사놀 30캡슐 (6개)
# 1           녹십초생활건강 쏘팔메토 옥타코사놀 30캡슐 (6개)
# 2             1 종근당건강 프로메가 알티지 오메가3 60캡슐
# 3           2 내츄럴플러스 알티지 오메가3 1200 180캡슐
# 4            3 메이플트리 오메가-3 맥스 1100 180캡슐
# 5                        4 펄세스 크릴56 30캡슐
# 6     5 지엔엠라이프 GNM자연의품격 rTG알티지 오메가3 60캡슐
# 7              6 종근당건강 프로메가 오메가3 파워 60캡슐
# 8         7 스포츠리서치 오메가3 피쉬 오일 180캡슐 (해외)
# 9          8 중외제약 프리미엄 리얼메디 크릴오일 58 30캡슐
# 10     9 에스더포뮬러 파이토 오메가 플러스D 1000IU 60캡슐
# 11            10 코스트코 커클랜드 슈퍼 오메가3 180캡슐
# 12   11 지엔엠라이프 GNM자연의품격 크릴오일맥스 1000 30캡슐
# 13        12 내츄럴플러스 프리미엄 오메가3 1100 180캡슐
# 14              13 고려은단 퓨어 알티지 오메가3 60캡슐
# 15            14 뉴트리코어 식물성 알티지 오메가3 30캡슐
# 16        15 네추럴라이즈 엔쵸비 오메가-3 1000 180캡슐
# 17          16 코스트코 커클랜드 크릴오일 160캡슐 (해외)
# 18      17 헬스밸런스 베스처 오메가-3 골드 1100 180캡슐
# 19       18 지엔엠라이프 GNM자연의품격 루테인오메가3 30캡슐
# 20              19 나우푸드 오메가-3 500캡슐 (해외)
# 21            20 노르딕내츄럴 오메가-3 180캡슐 (해외)
# ...

# %%
omega_names_df.drop_duplicates()
omega_names_df=omega_names_df.drop(index=0)
omega_names_df=omega_names_df.drop(index=1)

# %%
omega_names_df=omega_names_df.reset_index(drop=True)
omega_names_df
# Out:
#                               omega_name
# 0             1 종근당건강 프로메가 알티지 오메가3 60캡슐
# 1           2 내츄럴플러스 알티지 오메가3 1200 180캡슐
# 2            3 메이플트리 오메가-3 맥스 1100 180캡슐
# 3                        4 펄세스 크릴56 30캡슐
# 4     5 지엔엠라이프 GNM자연의품격 rTG알티지 오메가3 60캡슐
# 5              6 종근당건강 프로메가 오메가3 파워 60캡슐
# 6         7 스포츠리서치 오메가3 피쉬 오일 180캡슐 (해외)
# 7          8 중외제약 프리미엄 리얼메디 크릴오일 58 30캡슐
# 8      9 에스더포뮬러 파이토 오메가 플러스D 1000IU 60캡슐
# 9             10 코스트코 커클랜드 슈퍼 오메가3 180캡슐
# 10   11 지엔엠라이프 GNM자연의품격 크릴오일맥스 1000 30캡슐
# 11        12 내츄럴플러스 프리미엄 오메가3 1100 180캡슐
# 12              13 고려은단 퓨어 알티지 오메가3 60캡슐
# 13            14 뉴트리코어 식물성 알티지 오메가3 30캡슐
# 14        15 네추럴라이즈 엔쵸비 오메가-3 1000 180캡슐
# 15          16 코스트코 커클랜드 크릴오일 160캡슐 (해외)
# 16      17 헬스밸런스 베스처 오메가-3 골드 1100 180캡슐
# 17       18 지엔엠라이프 GNM자연의품격 루테인오메가3 30캡슐
# 18              19 나우푸드 오메가-3 500캡슐 (해외)
# 19            20 노르딕내츄럴 오메가-3 180캡슐 (해외)
# 20           20 유니시티 오메가 라이프-3 리졸브 120캡슐
# 21          22 내츄럴플러스 알티지 오메가3 1200 60캡슐
# ...

# %%
from pandas import DataFrame
omega_comps_df = DataFrame(omega_comps,columns=["omega_comp"])
omega_comps_df
omega_comps_df=omega_comps_df.drop(index=0)
omega_comps_df=omega_comps_df.reset_index(drop=True)

# %%
omega_comps_df
# Out:
#                                            omega_comp
# 0   오메가3 / 형태: 캡슐,정 / 섭취횟수, 양: 1일 1회, 1회 2캡슐 / 총량:...
# 1   오메가3 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 2   오메가3 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 3   크릴오일 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 4   오메가3 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 2캡슐 ...
# 5   오메가3 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 6   오메가3 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 7   크릴오일 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 8   오메가3 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 2캡슐 ...
# 9   오메가3 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 10  크릴오일 / 형태: 캡슐,정 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 / 총량:...
# 11  오메가3 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 12  오메가3 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 13  오메가3 / 형태: 캡슐,정 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 / 총량:...
# 14  오메가3 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 15  크릴오일 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# ...

# %%
##킵
import pandas as pd
omega_df=pd.concat([omega_names_df,omega_comps_df],axis=1)
omega_df
# Out:
#                               omega_name  \
# 0             1 종근당건강 프로메가 알티지 오메가3 60캡슐
# 1           2 내츄럴플러스 알티지 오메가3 1200 180캡슐
# 2            3 메이플트리 오메가-3 맥스 1100 180캡슐
# 3                        4 펄세스 크릴56 30캡슐
# 4     5 지엔엠라이프 GNM자연의품격 rTG알티지 오메가3 60캡슐
# 5              6 종근당건강 프로메가 오메가3 파워 60캡슐
# 6         7 스포츠리서치 오메가3 피쉬 오일 180캡슐 (해외)
# 7          8 중외제약 프리미엄 리얼메디 크릴오일 58 30캡슐
# 8      9 에스더포뮬러 파이토 오메가 플러스D 1000IU 60캡슐
# 9             10 코스트코 커클랜드 슈퍼 오메가3 180캡슐
# 10   11 지엔엠라이프 GNM자연의품격 크릴오일맥스 1000 30캡슐
# 11        12 내츄럴플러스 프리미엄 오메가3 1100 180캡슐
# 12              13 고려은단 퓨어 알티지 오메가3 60캡슐
# 13            14 뉴트리코어 식물성 알티지 오메가3 30캡슐
# 14        15 네추럴라이즈 엔쵸비 오메가-3 1000 180캡슐
# 15          16 코스트코 커클랜드 크릴오일 160캡슐 (해외)
# 16      17 헬스밸런스 베스처 오메가-3 골드 1100 180캡슐
# 17       18 지엔엠라이프 GNM자연의품격 루테인오메가3 30캡슐
# 18              19 나우푸드 오메가-3 500캡슐 (해외)
# 19            20 노르딕내츄럴 오메가-3 180캡슐 (해외)
# 20           20 유니시티 오메가 라이프-3 리졸브 120캡슐
# 21          22 내츄럴플러스 알티지 오메가3 1200 60캡슐
# ...

# %%
from pandas import DataFrame
milk_names_df = DataFrame(milk_names,columns=["milk_name"])
milk_names_df
# Out:
#                             milk_name
# 0        녹십초생활건강 쏘팔메토 옥타코사놀 30캡슐 (6개)
# 1        녹십초생활건강 쏘팔메토 옥타코사놀 30캡슐 (6개)
# 2           1 녹십초생활건강 쏘팔메토 옥타코사놀 30캡슐
# 3             2 프라임생활건강 브이 맥스 울트라 60정
# 4    3 지엔엠라이프 GNM자연의품격 건강한 간 밀크씨슬 30정
# 5             4 헬스밸런스 베스처 밀크씨슬 골드 90정
# 6                     5 GNC 밀크씨슬 300정
# 7          6 CJ제일제당 리턴업 전립소 쏘팔메토 60캡슐
# 8          7 CJ제일제당 리턴업 전립소 쏘팔메토 90캡슐
# 9                8 GNC 밀크씨슬 120정 (해외)
# 10         9 일양약품 쏘팔메토 파워업+옥타코사놀 90캡슐
# 11              10 메이플트리 쏘팔메토 맥스 90캡슐
# 12                 11 닥터팜 쏘팔 코사놀 60캡슐
# 13    11 나우푸드 실리마린 300mg 200베지캡슐 (해외)
# 14   13 헬스밸런스 베스처 맨파워 쏘팔메토 프리미엄 180캡슐
# 15                 14 뉴트리코어 쏘팔메토 60캡슐
# 16             15 내츄럴플러스 밀크씨슬 플러스 30정
# 17          16 GNC 쏘팔메토 포뮬라 240정 (해외)
# 18              17 한미양행 헤파케어 골드 180캡슐
# 19              18 삼성제약 올바른 밀크씨슬9 30정
# 20         19 암웨이 뉴트리라이트 밀크씨슬 이엑스 60정
# 21        20 나우푸드 피지움&쏘팔메토 120캡슐 (해외)
# 22   21 더베이글 뉴트리디데이 프리미엄 간건강 밀크씨슬 30정
# 23             22 에이치엘사이언스 닥터슈퍼칸 30캡슐
# ...

# %%
milk_names_df.drop_duplicates()
milk_names_df=milk_names_df.drop(index=0)
milk_names_df=milk_names_df.drop(index=1)
milk_names_df=milk_names_df.reset_index(drop=True)
milk_names_df
# Out:
#                             milk_name
# 0           1 녹십초생활건강 쏘팔메토 옥타코사놀 30캡슐
# 1             2 프라임생활건강 브이 맥스 울트라 60정
# 2    3 지엔엠라이프 GNM자연의품격 건강한 간 밀크씨슬 30정
# 3             4 헬스밸런스 베스처 밀크씨슬 골드 90정
# 4                     5 GNC 밀크씨슬 300정
# 5          6 CJ제일제당 리턴업 전립소 쏘팔메토 60캡슐
# 6          7 CJ제일제당 리턴업 전립소 쏘팔메토 90캡슐
# 7                8 GNC 밀크씨슬 120정 (해외)
# 8          9 일양약품 쏘팔메토 파워업+옥타코사놀 90캡슐
# 9               10 메이플트리 쏘팔메토 맥스 90캡슐
# 10                 11 닥터팜 쏘팔 코사놀 60캡슐
# 11    11 나우푸드 실리마린 300mg 200베지캡슐 (해외)
# 12   13 헬스밸런스 베스처 맨파워 쏘팔메토 프리미엄 180캡슐
# 13                 14 뉴트리코어 쏘팔메토 60캡슐
# 14             15 내츄럴플러스 밀크씨슬 플러스 30정
# 15          16 GNC 쏘팔메토 포뮬라 240정 (해외)
# 16              17 한미양행 헤파케어 골드 180캡슐
# 17              18 삼성제약 올바른 밀크씨슬9 30정
# 18         19 암웨이 뉴트리라이트 밀크씨슬 이엑스 60정
# 19        20 나우푸드 피지움&쏘팔메토 120캡슐 (해외)
# 20   21 더베이글 뉴트리디데이 프리미엄 간건강 밀크씨슬 30정
# 21             22 에이치엘사이언스 닥터슈퍼칸 30캡슐
# 22           23 시너지월드와이즈 파워메토 플러스 30포
# 23              24 뉴트리코어 유기농 밀크씨슬 30정
# ...

# %%
# Out:
#                             yeobsan_name
# 0                1 뉴트리 에버콜라겐 인앤업 플러스 56정
# 1                    2 농심 라이필 더마 콜라겐 84정
# 2                 3 뉴트리 에버콜라겐 타임 비오틴 30포
# 3                     4 뉴트리 에버콜라겐 타임 30포
# 4             5 뉴트리원 비비랩 더 콜라겐 파우더 S 30포
# 5      6 광동제약 광동초이스 더 탱탱한 석류콜라겐 젤리스틱 10포
# 6                 7 드랍쉽 저분자 피쉬콜라겐 분말 1kg
# 7                     8 뉴트리코어 콜라겐 담다 15포
# 8          9 에이치케이이노엔 뉴틴 타트체리 콜라겐 스틱 30포
# 9                       10 순수식품 진짜석류 15포
# 10                  11 대상웰라이프 석류 콜라겐 15포
# 11            12 아모레퍼시픽 바이탈뷰티 슈퍼콜라겐 30앰플
# 12             13 뉴트리원 르 시크릿 더 석류콜라겐 14포
# 13                  14 종근당건강 아쿠아 콜라겐 30포
# 14           15 일동생활건강 일동 저분자 피쉬콜라겐C 30포
# 15       16 뉴트리원 뉴트리원라이프 비비랩 저분자 콜라겐 30포
# 16  17 중외제약 유기농 프리미엄 리얼메디 석류젤리스틱 마스터 15포
# 17                   18 제너럴밸런스 N 콜라겐 30포
# 18      19 사람과자연 초저분자 피쉬 콜라겐 트리펩타이드 300g
# 19             20 순수식품 저분자 콜라겐 500달톤 90정
# 20         21 트래디스바이오 더작 저분자 콜라겐 타블렛 60정
# 21               22 푸른건강 피쉬 콜라겐 지퍼팩 300g
# ...

# %%
from pandas import DataFrame
milk_comps_df = DataFrame(milk_comps,columns=["milk_comp"])
milk_comps_df=milk_comps_df.drop(index=0)
# milk_comps_df=milk_comps_df.reset_index(drop=True)
# milk_comps_df

# %%
milk_comps_df=milk_comps_df.reset_index(drop=True)
milk_comps_df
# Out:
#                                             milk_comp
# 0   쏘팔메토 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 1   쏘팔메토 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 2정 /...
# 2   밀크씨슬 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1정 /...
# 3   밀크씨슬 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1정 /...
# 4   밀크씨슬 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1~3정...
# 5   쏘팔메토 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 6   쏘팔메토 / 형태: 캡슐,정 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 / 총량:...
# 7   밀크씨슬 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1정 /...
# 8   쏘팔메토 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 9   쏘팔메토 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 10  쏘팔메토 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 11  밀크씨슬 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1~3캡...
# 12  쏘팔메토 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 13  쏘팔메토 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1캡슐 ...
# 14  밀크씨슬 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1정 /...
# 15  쏘팔메토 / 형태: 캡슐,정 / 성인 / 섭취횟수, 양: 1일 1회, 1회 1~2정...
# ...

# %%
##킵
import pandas as pd
milk_df=pd.concat([milk_names_df,milk_comps_df],axis=1)
milk_df
# Out:
#                             milk_name  \
# 0           1 녹십초생활건강 쏘팔메토 옥타코사놀 30캡슐
# 1             2 프라임생활건강 브이 맥스 울트라 60정
# 2    3 지엔엠라이프 GNM자연의품격 건강한 간 밀크씨슬 30정
# 3             4 헬스밸런스 베스처 밀크씨슬 골드 90정
# 4                     5 GNC 밀크씨슬 300정
# 5          6 CJ제일제당 리턴업 전립소 쏘팔메토 60캡슐
# 6          7 CJ제일제당 리턴업 전립소 쏘팔메토 90캡슐
# 7                8 GNC 밀크씨슬 120정 (해외)
# 8          9 일양약품 쏘팔메토 파워업+옥타코사놀 90캡슐
# 9               10 메이플트리 쏘팔메토 맥스 90캡슐
# 10                 11 닥터팜 쏘팔 코사놀 60캡슐
# 11    11 나우푸드 실리마린 300mg 200베지캡슐 (해외)
# 12   13 헬스밸런스 베스처 맨파워 쏘팔메토 프리미엄 180캡슐
# 13                 14 뉴트리코어 쏘팔메토 60캡슐
# 14             15 내츄럴플러스 밀크씨슬 플러스 30정
# 15          16 GNC 쏘팔메토 포뮬라 240정 (해외)
# 16              17 한미양행 헤파케어 골드 180캡슐
# 17              18 삼성제약 올바른 밀크씨슬9 30정
# 18         19 암웨이 뉴트리라이트 밀크씨슬 이엑스 60정
# 19        20 나우푸드 피지움&쏘팔메토 120캡슐 (해외)
# 20   21 더베이글 뉴트리디데이 프리미엄 간건강 밀크씨슬 30정
# 21             22 에이치엘사이언스 닥터슈퍼칸 30캡슐
# 22           23 시너지월드와이즈 파워메토 플러스 30포
# ...

# %%
from pandas import DataFrame
sig2_names_df = DataFrame(sig2_names,columns=["sig2_name"])
sig2_names_df
