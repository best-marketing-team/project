# %%
import pandas as pd
user_id=pd.read_excel("D:/workjisu/data/final_review/jisu_user_id_num.xlsx")

# %%
user_id
# Out:
#      종근당건강 시원하다 전립쎈 쏘팔메토, 60정, 2개 25,310  리턴업 전립소 쏘팔메토 아연, 60정, 1개 12,330  \
# 0                                1308594                          1308594
# 1                              116887865                        114609339
# 2                                4560834                          6901441
# 3                              118075501                        104679516
# 4                              100456818                          7044975
# ..                                   ...                              ...
# 995                            112254532                        109855123
# 996                            120043289                        110523148
# 997                             25950777                         50353307
# 998                            122990524                        104946185
# 999                            121799039                         11616966
#
#      메이플트리 쏘팔메토 맥스, 90정, 1개 15,820  중외제약 프리미엄 쏘팔메토, 60캡슐, 1개 13,900  \
# ...

# %%
user_id=user_id.dropna()

# %%
user_id
# Out:
#     종근당건강 시원하다 전립쎈 쏘팔메토, 60정, 2개 25,310  \
# 0                                 웅장해진다
# 1                                   노*욱
# 2                                   김*기
# 3                                   신*식
# 4                                   김*주
# ..                                  ...
# 995                                그가이거
# 996                                 박*희
# 997                                 박헌도
# 998                                 황*배
# 999                                 박*수
#
#      종근당건강 시원하다 전립쎈 쏘팔메토, 60정, 2개 25,310.1 리턴업 전립소 쏘팔메토 아연, 60정, 1개 12,330  \
# 0                                1308594.0                           웅장해진다
# 1                              116887865.0                              이*
# 2                                4560834.0                             장*연
# 3                              118075501.0                             홍용기
# 4                              100456818.0                             문*경
# ...
